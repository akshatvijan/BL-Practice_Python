# %% [markdown]
# Lambda function lambda function is also called as anonymous function as for normal function we neend to write def key word but in lmbda function we can proccess without def key word we need to write is lambda keyword

# %%
str="internship" 
upper=lambda string:string.upper() 
print(upper(str))

# %%
maximum=lambda a,b:a if(a>b) else b
print(maximum(10,20))

# %% [markdown]
# Map

# %%
a=[1,2,3,4,5]
double_list=list(map(lambda x:x*2,a))
print(double_list)
# Out:
# [2, 4, 6, 8, 10]
